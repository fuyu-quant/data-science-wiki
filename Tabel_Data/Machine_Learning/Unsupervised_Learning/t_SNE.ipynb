# %% [markdown]
# <a href="https://colab.research.google.com/github/ToumaTanaka/Data_Science/blob/main/Tabel_Data/Machine_Learning/Unsupervised_Learning/t_SNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # t-SNE
# t-SNEは高次元データの情報を保持したまま、低次元データに圧縮する手法である。
# 以下では、FashionMNISTの画像データを二次元に圧縮し二次元散布図に可視化する。

# %%
#以下がt-SNEに必要なコード
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torchvision
import torchvision.transforms as transforms

# %%
#データの読み込み
visualizeset = torchvision.datasets.FashionMNIST(root='./data', train=False, download=True)

images = visualizeset.test_data
labels = visualizeset.test_labels

# 画像をベクトル化する
images = images.numpy().reshape(len(images), -1)
# t-SNEするには多すぎるので削減
_, images, _, labels = train_test_split(images, labels, test_size=0.3)

# %%
images.shape
# Out:
# (3000, 784)

# %%
#t-SNEを実行し二次元データにする
tsne = TSNE(n_components=2,random_state=42)
x_reduced = tsne.fit_transform(images)

# %%
x_reduced.shape
# Out:
# (3000, 2)

# %% [markdown]
# ##### 次元圧縮が完了したので可視化する

# %%
plt.figure(figsize=(13,7))
plt.scatter(x_reduced[:,0],x_reduced[:,1],c=labels,
            cmap='jet',s=15,alpha = 0.5)
plt.show()
