# %% [markdown]
# # pycaret
# * https://github.com/pycaret/pycaret
# * 複数の予測モデルで計算を行い比較ができる
# * Classification,Regression,Clustering,Time Series,異常検知,Association Rules,NLP(Topic Model)などが行える

# %%
# %%capture
# !pip install pycaret

# %%
import numpy as np
import pandas as pd
import torch

from sklearn import datasets
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# pycaretで必要なもの
from pycaret.classification import *

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target_names[iris.target]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# 学習を実行する前に必要なセットアップ
# session_idはseed値
exp_mclf101 = setup(data = df, target = 'target', session_id = 3655)
# Out:
# <style type="text/css">
# #T_e5567_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e5567">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5567_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e5567_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5567_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5567_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e5567_row0_col1" class="data row0 col1" >3655</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5567_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e5567_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5567_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_e5567_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5567_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_e5567_row3_col1" class="data row3 col1" >setosa: 0, versicolor: 1, virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e5567_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_e5567_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e5567_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_e5567_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e5567_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_e5567_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e5567_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_e5567_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e5567_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_e5567_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e5567_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_e5567_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e5567_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_e5567_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e5567_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_e5567_row11_col1" class="data row11 col1" >(104, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e5567_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_e5567_row12_col1" class="data row12 col1" >(46, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e5567_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_e5567_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e5567_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_e5567_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e5567_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_e5567_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e5567_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_e5567_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e5567_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_e5567_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e5567_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_e5567_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e5567_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_e5567_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e5567_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_e5567_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e5567_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_e5567_row21_col1" class="data row21 col1" >4112</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e5567_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_e5567_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e5567_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_e5567_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e5567_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_e5567_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e5567_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_e5567_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e5567_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_e5567_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e5567_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_e5567_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e5567_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_e5567_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e5567_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_e5567_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e5567_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_e5567_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td

# %% [markdown]
# ### モデルごとの結果の表示

# %%
# 全ての実行可能なモデルでの精度の比較
# このモデルではQDA(二次判別分析)やLDA(線形判別分析)が高い精度を出力していることがわかる
best = compare_models(fold = 5,  # foldの数を設定
                      sort = 'AUC', 　　# sortする指標
                      n_select = 15　　　# 表示する上位のモデル数(今現在15がマックス)
                     )
# Out:
# <style type="text/css">
# #T_f2e36 th {
#   text-align: left;
# }
# #T_f2e36_row0_col0, #T_f2e36_row1_col0, #T_f2e36_row1_col1, #T_f2e36_row1_col2, #T_f2e36_row1_col3, #T_f2e36_row1_col4, #T_f2e36_row1_col5, #T_f2e36_row1_col6, #T_f2e36_row1_col7, #T_f2e36_row2_col0, #T_f2e36_row2_col2, #T_f2e36_row3_col0, #T_f2e36_row3_col1, #T_f2e36_row3_col2, #T_f2e36_row3_col3, #T_f2e36_row3_col4, #T_f2e36_row3_col5, #T_f2e36_row3_col6, #T_f2e36_row3_col7, #T_f2e36_row4_col0, #T_f2e36_row4_col1, #T_f2e36_row4_col2, #T_f2e36_row4_col3, #T_f2e36_row4_col4, #T_f2e36_row4_col5, #T_f2e36_row4_col6, #T_f2e36_row4_col7, #T_f2e36_row5_col0, #T_f2e36_row5_col1, #T_f2e36_row5_col2, #T_f2e36_row5_col3, #T_f2e36_row5_col4, #T_f2e36_row5_col5, #T_f2e36_row5_col6, #T_f2e36_row5_col7, #T_f2e36_row6_col0, #T_f2e36_row6_col1, #T_f2e36_row6_col2, #T_f2e36_row6_col3, #T_f2e36_row6_col4, #T_f2e36_row6_col5, #T_f2e36_row6_col6, #T_f2e36_row6_col7, #T_f2e36_row7_col0, #T_f2e36_row7_col1, #T_f2e36_row7_col2, #T_f2e36_row7_col3, #T_f2e36_row7_col4, #T_f2e36_row7_col5, #T_f2e36_row7_col6, #T_f2e36_row7_col7, #T_f2e36_row8_col0, #T_f2e36_row8_col1, #T_f2e36_row8_col2, #T_f2e36_row8_col3, #T_f2e36_row8_col4, #T_f2e36_row8_col5, #T_f2e36_row8_col6, #T_f2e36_row8_col7, #T_f2e36_row9_col0, #T_f2e36_row9_col1, #T_f2e36_row9_col2, #T_f2e36_row9_col3, #T_f2e36_row9_col4, #T_f2e36_row9_col5, #T_f2e36_row9_col6, #T_f2e36_row9_col7, #T_f2e36_row10_col0, #T_f2e36_row10_col1, #T_f2e36_row10_col2, #T_f2e36_row10_col3, #T_f2e36_row10_col4, #T_f2e36_row10_col5, #T_f2e36_row10_col6, #T_f2e36_row10_col7, #T_f2e36_row11_col0, #T_f2e36_row11_col1, #T_f2e36_row11_col2, #T_f2e36_row11_col3, #T_f2e36_row11_col4, #T_f2e36_row11_col5, #T_f2e36_row11_col6, #T_f2e36_row11_col7, #T_f2e36_row12_col0, #T_f2e36_row12_col1, #T_f2e36_row12_col2, #T_f2e36_row12_col3, #T_f2e36_row12_col4, #T_f2e36_row12_col5, #T_f2e36_row12_col6, #T_f2e36_row12_col7, #T_f2e36_row13_col0, #T_f2e36_row13_col1, #T_f2e36_row13_col2, #T_f2e36_row13_col3, #T_f2e36_row13_col4, #T_f2e36_row13_col5, #T_f2e36_row13_col6, #T_f2e36_row13_col7, #T_f2e36_row14_col0, #T_f2e36_row14_col1, #T_f2e36_row14_col2, #T_f2e36_row14_col3, #T_f2e36_row14_col4, #T_f2e36_row14_col5, #T_f2e36_row14_col6, #T_f2e36_row14_col7 {
#   text-align: left;
# }
# #T_f2e36_row0_col1, #T_f2e36_row0_col2, #T_f2e36_row0_col3, #T_f2e36_row0_col4, #T_f2e36_row0_col5, #T_f2e36_row0_col6, #T_f2e36_row0_col7, #T_f2e36_row2_col1, #T_f2e36_row2_col3, #T_f2e36_row2_col4, #T_f2e36_row2_col5, #T_f2e36_row2_col6, #T_f2e36_row2_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f2e36_row0_col8, #T_f2e36_row2_col8, #T_f2e36_row12_col8, #T_f2e36_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_f2e36_row1_col8, #T_f2e36_row3_col8, #T_f2e36_row4_col8, #T_f2e36_row5_col8, #T_f2e36_row6_col8, #T_f2e36_row7_col8, #T_f2e36_row8_col8, #T_f2e36_row9_col8, #T_f2e36_row10_col8, #T_f2e36_row11_col8, #T_f2e36_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f2e36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2e36_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f2e36_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f2e36_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f2e36_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f2e36_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f2e36_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f2e36_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f2e36_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f2e36_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2e36_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_f2e36_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_f2e36_row0_col1" class="data row0 col1" >0.9714</td>
#       <td id="T_f2e36_row0_col2" class="data row0 col2" >0.9985</td>
#       <td id="T_f2e36_row0_col3" class="data row0 col3" >0.9750</td>
#       <td id="T_f2e36_row0_col4" class="data row0 col4" >0.9767</td>
#       <td id="T_f2e36_row0_col5" class="data row0 col5" >0.9712</td>
#       <td id="T_f2e36_row0_col6" class="data row0 col6" >0.9568</td>
#       <td id="T_f2e36_row0_col7" class="data row0 col7" >0.9599</td>
#       <td id="T_f2e36_row0_col8" class="data row0 col8" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_f2e36_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_f2e36_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_f2e36_row1_col1" class="data row1 col1" >0.9324</td>
#       <td id="T_f2e36_row1_col2" class="data row1 col2" >0.9975</td>
#       <td id="T_f2e36_row1_col3" class="data row1 col3" >0.9417</td>
#       <td id="T_f2e36_row1_col4" class="data row1 col4" >0.9476</td>
#       <td id="T_f2e36_row1_col5" class="data row1 col5" >0.9314</td>
#       <td id="T_f2e36_row1_col6" class="data row1 col6" >0.8981</td>
#       <td id="T_f2e36_row1_col7" class="data row1 col7" >0.9070</td>
#       <td id="T_f2e36_row1_col8" class="data row1 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_f2e36_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_f2e36_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f2e36_row2_col1" class="data row2 col1" >0.9714</td>
#       <td id="T_f2e36_row2_col2" class="data row2 col2" >0.9972</td>
#       <td id="T_f2e36_row2_col3" class="data row2 col3" >0.9750</td>
#       <td id="T_f2e36_row2_col4" class="data row2 col4" >0.9767</td>
#       <td id="T_f2e36_row2_col5" class="data row2 col5" >0.9712</td>
#       <td id="T_f2e36_row2_col6" class="data row2 col6" >0.9568</td>
#       <td id="T_f2e36_row2_col7" class="data row2 col7" >0.9599</td>
#       <td id="T_f2e36_row2_col8" class="data row2 col8" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_f2e36_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_f2e36_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_f2e36_row3_col1" class="data row3 col1" >0.9519</td>
#       <td id="T_f2e36_row3_col2" class="data row3 col2" >0.9958</td>
#       <td id="T_f2e36_row3_col3" class="data row3 col3" >0.9583</td>
#       <td id="T_f2e36_row3_col4" class="data row3 col4" >0.9629</td>
#       <td id="T_f2e36_row3_col5" class="data row3 col5" >0.9511</td>
#       <td id="T_f2e36_row3_col6" class="data row3 col6" >0.9277</td>
#       <td id="T_f2e36_row3_col7" class="data row3 col7" >0.9341</td>
#       <td id="T_f2e36_row3_col8" class="data row3 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_f2e36_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_f2e36_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_f2e36_row4_col1" class="data row4 col1" >0.9519</td>
#       <td id="T_f2e36_row4_col2" class="data row4 col2" >0.9924</td>
#       <td id="T_f2e36_row4_col3" class="data row4 col3" >0.9583</td>
#       <td id="T_f2e36_row4_col4" class="data row4 col4" >0.9629</td>
#       <td id="T_f2e36_row4_col5" class="data row4 col5" >0.9511</td>
#       <td id="T_f2e36_row4_col6" class="data row4 col6" >0.9277</td>
#       <td id="T_f2e36_row4_col7" class="data row4 col7" >0.9341</td>
#       <td id="T_f2e36_row4_col8" class="data row4 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_f2e36_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_f2e36_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_f2e36_row5_col1" class="data row5 col1" >0.9424</td>
#       <td id="T_f2e36_row5_col2" class="data row5 col2" >0.9897</td>
#       <td id="T_f2e36_row5_col3" class="data row5 col3" >0.9500</td>
#       <td id="T_f2e36_row5_col4" class="data row5 col4" >0.9545</td>
#       <td id="T_f2e36_row5_col5" class=

# %% [markdown]
# ### モデルの作成

# %%
et = create_model('et')
# Out:
# <style type="text/css">
# #T_3ae4f_row10_col0, #T_3ae4f_row10_col1, #T_3ae4f_row10_col2, #T_3ae4f_row10_col3, #T_3ae4f_row10_col4, #T_3ae4f_row10_col5, #T_3ae4f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3ae4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ae4f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3ae4f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3ae4f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3ae4f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3ae4f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3ae4f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3ae4f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ae4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ae4f_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_3ae4f_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_3ae4f_row0_col2" class="data row0 col2" >0.9167</td>
#       <td id="T_3ae4f_row0_col3" class="data row0 col3" >0.9273</td>
#       <td id="T_3ae4f_row0_col4" class="data row0 col4" >0.9076</td>
#       <td id="T_3ae4f_row0_col5" class="data row0 col5" >0.8625</td>
#       <td id="T_3ae4f_row0_col6" class="data row0 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ae4f_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_3ae4f_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_3ae4f_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_3ae4f_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_3ae4f_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_3ae4f_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_3ae4f_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ae4f_row2_col0" class="data row2 col0" >0.7273</td>
#       <td id="T_3ae4f_row2_col1" class="data row2 col1" >0.9740</td>
#       <td id="T_3ae4f_row2_col2" class="data row2 col2" >0.7500</td>
#       <td id="T_3ae4f_row2_col3" class="data row2 col3" >0.8442</td>
#       <td id="T_3ae4f_row2_col4" class="data row2 col4" >0.6826</td>
#       <td id="T_3ae4f_row2_col5" class="data row2 col5" >0.5875</td>
#       <td id="T_3ae4f_row2_col6" class="data row2 col6" >0.6674</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3ae4f_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_3ae4f_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_3ae4f_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_3ae4f_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_3ae4f_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_3ae4f_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_3ae4f_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3ae4f_row4_col0" class="data row4 col0" >0.9000</td>
#       <td id="T_3ae4f_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_3ae4f_row4_col2" class="data row4 col2" >0.9167</td>
#       <td id="T_3ae4f_row4_col3" class="data row4 col3" >0.9200</td>
#       <td id="T_3ae4f_row4_col4" class="data row4 col4" >0.8984</td>
#       <td id="T_3ae4f_row4_col5" class="data row4 col5" >0.8438</td>
#       <td id="T_3ae4f_row4_col6" class="data row4 col6" >0.8573</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3ae4f_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_3ae4f_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_3ae4f_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_3ae4f_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_3ae4f_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_3ae4f_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_3ae4f_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3ae4f_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_3ae4f_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_3ae4f_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_3ae4f_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_3ae4f_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_3ae4f_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_3ae4f_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3ae4f_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_3ae4f_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_3ae4f_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_3ae4f_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_3ae4f_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_3ae4f_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_3ae4f_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3ae4f_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_3ae4f_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_3ae4f_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_3ae4f_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_3ae4f_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_3ae4f_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_3ae4f_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3ae4f_row9_col0" class="data row9 col0" >0.9000</td>
#       <td id="T_3ae4f_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_3ae4f_row9_col2" class="data row9 col2" >0.9167</td>
#       <td id="T_3ae4f_row9_col3" class="data row9 col3" >0.9250</td>
#       <td id="T_3ae4f_row9_col4" class="data row9 col4" >0.9000</td>
#       <td id="T_3ae4f_row9_col5" class="data row9 col5" >0.8507</td>
#       <td id="T_3ae4f_row9_col6" class="data row9 col6" >0.8636</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3ae4f_row10_col0" class="data row10 col0" >0.9436</td>
#       <td id="T_3ae4f_row10_col1" class="data row10 col1" >0.9974</td>
#       <td id="T_3ae4f_row10_col2" class="data row10 col2" >0.9500</td>
#       <td id="T_3ae4f_row10_col3" class="data row10 col3" >0.9616</td>
#       <td id="T_3ae4f_row10_col4" class="data row10 col4" >0.9389</td>
#       <td id="T_3ae4f_row10_col5" class="data row10 col5" >0.9144</td>
#       <td id="T_3ae4f_row10_col6" class="data row10 col6" >0.9262</td>
#     </tr>
#     <tr>
#       <th id="T_3ae4f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3ae4f_row11_col0" class="data row11 col0" >0.0842</td>
#       <td id="T_3ae4f_row11_col1" class="data row11 col1" >0.0078</td>
#       <td id="T_3ae4f_row11_col2" class="data row11 col2" >0.0764</td>
#       <td id="T_3ae4f_row11_col3" class="data row11 col3" >0.0519</td>
#       <td id="T_3ae4f_row11_col4

# %%
# 学習したExtra Trees Classifierのハイパーパラメータ
print(et)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=3655, verbose=0,
#                      warm_start=False)

# %% [markdown]
# ### モデルのハイパラチューニング

# %%
tuned_et = tune_model(et)
# Out:
# <style type="text/css">
# #T_14da6_row10_col0, #T_14da6_row10_col1, #T_14da6_row10_col2, #T_14da6_row10_col3, #T_14da6_row10_col4, #T_14da6_row10_col5, #T_14da6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_14da6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14da6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_14da6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_14da6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_14da6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_14da6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_14da6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_14da6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14da6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14da6_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_14da6_row0_col1" class="data row0 col1" >0.9870</td>
#       <td id="T_14da6_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_14da6_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_14da6_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_14da6_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_14da6_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14da6_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_14da6_row1_col1" class="data row1 col1" >0.9870</td>
#       <td id="T_14da6_row1_col2" class="data row1 col2" >0.9167</td>
#       <td id="T_14da6_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_14da6_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_14da6_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_14da6_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14da6_row2_col0" class="data row2 col0" >0.7273</td>
#       <td id="T_14da6_row2_col1" class="data row2 col1" >0.9481</td>
#       <td id="T_14da6_row2_col2" class="data row2 col2" >0.7500</td>
#       <td id="T_14da6_row2_col3" class="data row2 col3" >0.8442</td>
#       <td id="T_14da6_row2_col4" class="data row2 col4" >0.6826</td>
#       <td id="T_14da6_row2_col5" class="data row2 col5" >0.5875</td>
#       <td id="T_14da6_row2_col6" class="data row2 col6" >0.6674</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14da6_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_14da6_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_14da6_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_14da6_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_14da6_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_14da6_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_14da6_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14da6_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_14da6_row4_col1" class="data row4 col1" >0.9000</td>
#       <td id="T_14da6_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_14da6_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_14da6_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_14da6_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_14da6_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_14da6_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_14da6_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_14da6_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_14da6_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_14da6_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_14da6_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_14da6_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_14da6_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_14da6_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_14da6_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_14da6_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_14da6_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_14da6_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_14da6_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_14da6_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_14da6_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_14da6_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_14da6_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_14da6_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_14da6_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_14da6_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_14da6_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_14da6_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_14da6_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_14da6_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_14da6_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_14da6_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_14da6_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_14da6_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_14da6_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_14da6_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_14da6_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_14da6_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_14da6_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_14da6_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_14da6_row10_col0" class="data row10 col0" >0.9636</td>
#       <td id="T_14da6_row10_col1" class="data row10 col1" >0.9822</td>
#       <td id="T_14da6_row10_col2" class="data row10 col2" >0.9667</td>
#       <td id="T_14da6_row10_col3" class="data row10 col3" >0.9771</td>
#       <td id="T_14da6_row10_col4" class="data row10 col4" >0.9590</td>
#       <td id="T_14da6_row10_col5" class="data row10 col5" >0.9450</td>
#       <td id="T_14da6_row10_col6" class="data row10 col6" >0.9541</td>
#     </tr>
#     <tr>
#       <th id="T_14da6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_14da6_row11_col0" class="data row11 col0" >0.0833</td>
#       <td id="T_14da6_row11_col1" class="data row11 col1" >0.0314</td>
#       <td id="T_14da6_row11_col2" class="data row11 col2" >0.0764</td>
#       <td id="T_14da6_row11_col3" class="data row11 col3" >0.0493</td>
#       <td id="T_14da6_row11_col4

# %%
# チューニングしたモデルのハイパーパラメータ
print(tuned_et)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight='balanced',
#                      criterion='gini', max_depth=1, max_features=1.0,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.01, min_impurity_split=None,
#                      min_samples_leaf=6, min_samples_split=10,
#                      min_weight_fraction_leaf=0.0, n_estimators=220, n_jobs=-1,
#                      oob_score=False, random_state=3655, verbose=0,
#                      warm_start=False)

# %% [markdown]
# ### 混同行列

# %%
plot_model(tuned_et, plot = 'confusion_matrix')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %% [markdown]
# ### クラスごとの精度

# %%
plot_model(tuned_et, plot = 'class_report')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %% [markdown]
# ### 誤分類の可視化

# %%
plot_model(tuned_et, plot = 'error')

# %% [markdown]
# ### 未知のデータに対する予測
# * ここでは同じデータを予測している

# %%
unseen_predictions = predict_model(tuned_et, data=df)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_78753">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78753_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_78753_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_78753_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_78753_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_78753_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_78753_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_78753_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_78753_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78753_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78753_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_78753_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_78753_row0_col2" class="data row0 col2" >0.9921</td>
#       <td id="T_78753_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_78753_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_78753_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_78753_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_78753_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#   </tbody>
# </table>
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target   Label   Score
# 0  setosa  setosa  0.8615
# 1  setosa  setosa  0.8555
# 2  setosa  setosa  0.8584
# 3  setosa  setosa  0.8555
# 4  setosa  setosa  0.8615

# %% [markdown]
# ### モデルの保存

# %%
# モデルのpklファイルが作られる
save_model(tuned_et,'Model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='target',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strat...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight='balanced', criterion='gini',
#                                        max_depth=1, max_features=1.0,
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.01,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=6, min_samples_split=10,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=220, n_jobs=-1,
#                                        oob_score=False, random_state=3655,
#                                        verbose=0, warm_start=False)]],
#           verbose=False),
#  'Model.pkl')

# %% [markdown]
# ### 保存したモデルの読み込み

# %%
saved_final_model = load_model('Model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_model, data=df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8ad30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ad30_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8ad30_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8ad30_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8ad30_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8ad30_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8ad30_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8ad30_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8ad30_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ad30_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ad30_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_8ad30_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_8ad30_row0_col2" class="data row0 col2" >0.9921</td>
#       <td id="T_8ad30_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8ad30_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8ad30_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_8ad30_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_8ad30_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
new_prediction.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target   Label   Score
# 0  setosa  setosa  0.8615
# 1  setosa  setosa  0.8555
# 2  setosa  setosa  0.8584
# 3  setosa  setosa  0.8555
# 4  setosa  setosa  0.8615
