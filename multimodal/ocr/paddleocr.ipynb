# %% [markdown]
# # Paddleocr

# %% [markdown]
# PaddleOCRは、中国の企業Baiduが開発した光学式文字認識（OCR）モデルで、2020年9月に公開されました​1​。このツールはBaiduのPaddlePaddle深層学習フレームワークを基盤とし、複数の言語（80以上）をサポートする特徴を持っています​2​​3​。また、PaddleOCRは、データ生成、モデル訓練、圧縮、推論、そして展開の全プロセスを通じて、OCRに関連するさまざまな最先端のアルゴリズムをサポートし、産業用の特色を持つモデルやソリューションを提供します​4​。
# - GitHub:https://github.com/PaddlePaddle/PaddleOCR
# - Pypi:https://pypi.org/project/paddleocr/

# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyu-quant/data-science-wiki/blob/develop/multimodal/ocr/paddleocr.ipynb" target="_blank" rel="noopener noreferrer"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install "paddleocr>=2.0.1"
# !pip install paddlepaddle

# %%
from paddleocr import PaddleOCR,draw_ocr

from PIL import Image
import requests

# %% [markdown]
# ### データの用意

# %%
url = "https://raw.githubusercontent.com/fuyu-quant/data-science-wiki/main/images/logo1.png"
image = Image.open(requests.get(url, stream=True).raw).convert("RGB")
image.save("/content/cat.jpg", "JPEG")
image
# Out:
# <PIL.Image.Image image mode=RGB size=1472x403>

# %%
image.save("/content/samle.jpg", "JPEG")

# %% [markdown]
# ### Paddleocrの実行
# 以下の言語に対応している
# * 中国語:'ch'
# * 英語:'en'
# * フランス語:'french'
# * ドイツ語:'german'
# * 韓国語:'korean'
# * 日本語:'japan'

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en')

img_path = '/content/samle.jpg'
result = ocr.ocr(img_path, cls=True)
for idx in range(len(result)):
    res = result[idx]
    for line in res:
        print(line)
# Out:
# [2023/10/30 05:51:44] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path
# ...
