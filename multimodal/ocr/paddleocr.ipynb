# %% [markdown]
# # Paddleocr

# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyu-quant/data-science-wiki/blob/develop/multimodal/ocr/paddleocr.ipynb" target="_blank" rel="noopener noreferrer"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# Collecting paddleocr>=2.0.1
#   Downloading paddleocr-2.7.0.3-py3-none-any.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.7/465.7 kB 13.6 MB/s eta 0:00:0000:01
# Collecting shapely (from paddleocr>=2.0.1)
#   Downloading shapely-2.0.2-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.8 MB/s eta 0:00:00a 0:00:01
# Collecting scikit-image (from paddleocr>=2.0.1)
#   Downloading scikit_image-0.22.0-cp39-cp39-macosx_12_0_arm64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 80.6 MB/s eta 0:00:00a 0:00:01
# Collecting imgaug (from paddleocr>=2.0.1)
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 68.7 MB/s eta 0:00:00
# Collecting pyclipper (from paddleocr>=2.0.1)
#   Downloading pyclipper-1.3.0.post5-cp39-cp39-macosx_10_9_universal2.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 35.0 MB/s eta 0:00:00
# Collecting lmdb (from paddleocr>=2.0.1)
#   Downloading lmdb-1.4.1.tar.gz (881 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.5/881.5 kB 62.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (4.65.0)
# Requirement already satisfied: numpy in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (1.25.2)
# Collecting visualdl (from paddleocr>=2.0.1)
#   Downloading visualdl-2.5.3-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 86.9 MB/s eta 0:00:00:00:0100:01
# Collecting rapidfuzz (from paddleocr>=2.0.1)
#   Downloading rapidfuzz-3.4.0-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.2 MB/s eta 0:00:00
# Collecting opencv-python<=4.6.0.66 (from paddleocr>=2.0.1)
#   Downloading opencv_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (30.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.0/30.0 MB 43.1 MB/s eta 0:00:0000:0100:01
# Collecting opencv-contrib-python<=4.6.0.66 (from paddleocr>=2.0.1)
#   Downloading opencv_contrib_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (38.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 11.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cython in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (3.0.0)
# Collecting lxml (from paddleocr>=2.0.1)
#   Using cached lxml-4.9.3.tar.gz (3.6 MB)
#   Preparing metadata (setup.py) ... done
# Collecting premailer (from paddleocr>=2.0.1)
#   Downloading premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Collecting openpyxl (from paddleocr>=2.0.1)
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 33.6 MB/s eta 0:00:00
# Collecting attrdict (from paddleocr>=2.0.1)
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting PyMuPDF<1.21.0 (from paddleocr>=2.0.1)
#   Downloading PyMuPDF-1.20.2.tar.gz (90.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 MB 30.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=10.0.0 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (10.0.1)
# Requirement already satisfied: pyyaml in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (6.0.1)
# Collecting python-docx (from paddleocr>=2.0.1)
#   Downloading python_docx-1.0.1-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.4/237.4 kB 32.6 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (4.12.2)
# Requirement already satisfied: fonttools>=4.24.0 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (4.43.0)
# Requirement already satisfied: fire>=0.3.0 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from paddleocr>=2.0.1) (0.5.0)
# Collecting pdf2docx (from paddleocr>=2.0.1)
#   Downloading pdf2docx-0.5.6-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.4/148.4 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from fire>=0.3.0->paddleocr>=2.0.1) (1.16.0)
# Requirement already satisfied: termcolor in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.5)
# Requirement already satisfied: scipy in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from imgaug->paddleocr>=2.0.1) (1.9.3)
# Requirement already satisfied: matplotlib in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from imgaug->paddleocr>=2.0.1) (3.8.0)
# Collecting imageio (from imgaug->paddleocr>=2.0.1)
#   Downloading imageio-2.31.6-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 36.3 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.8 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from scikit-image->paddleocr>=2.0.1) (3.1)
# Collecting tifffile>=2022.8.12 (from scikit-image->paddleocr>=2.0.1)
#   Downloading tifffile-2023.9.26-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 kB 32.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from scikit-image->paddleocr>=2.0.1) (23.2)
# Collecting lazy_loader>=0.3 (from scikit-image->paddleocr>=2.0.1)
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Collecting et-xmlfile (from openpyxl->paddleocr>=2.0.1)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing-extensions in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from python-docx->paddleocr>=2.0.1) (4.8.0)
# Collecting cssselect (from premailer->paddleocr>=2.0.1)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting cssutils (from premailer->paddleocr>=2.0.1)
#   Downloading cssutils-2.9.0-py3-none-any.whl (398 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.5/398.5 kB 46.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from premailer->paddleocr>=2.0.1) (2.31.0)
# Collecting cachetools (from premailer->paddleocr>=2.0.1)
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting bce-python-sdk (from visualdl->paddleocr>=2.0.1)
#   Downloading bce_python_sdk-0.8.92-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 kB 30.8 MB/s eta 0:00:00
# Collecting flask>=1.1.1 (from visualdl->paddleocr>=2.0.1)
#   Downloading flask-3.0.0-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 14.2 MB/s eta 0:00:00
# Collecting Flask-Babel>=3.0.0 (from visualdl->paddleocr>=2.0.1)
#   Downloading flask_babel-4.0.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: protobuf>=3.20.0 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from visualdl->paddleocr>=2.0.1) (4.24.3)
# Requirement already satisfied: pandas in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from visualdl->paddleocr>=2.0.1) (2.1.1)
# Collecting rarfile (from visualdl->paddleocr>=2.0.1)
#   Downloading rarfile-4.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: psutil in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from visualdl->paddleocr>=2.0.1) (5.9.5)
# Collecting Werkzeug>=3.0.0 (from flask>=1.1.1->visualdl->paddleocr>=2.0.1)
#   Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 37.7 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.1.2)
# Collecting itsdangerous>=2.1.2 (from flask>=1.1.1->visualdl->paddleocr>=2.0.1)
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=8.1.3 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (8.1.7)
# Collecting blinker>=1.6.2 (from flask>=1.1.1->visualdl->paddleocr>=2.0.1)
#   Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (6.8.0)
# Requirement already satisfied: Babel>=2.12 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2.12.1)
# Requirement already satisfied: pytz>=2022.7 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2023.3.post1)
# Collecting pycryptodome>=3.8.0 (from bce-python-sdk->visualdl->paddleocr>=2.0.1)
#   Downloading pycryptodome-3.19.0-cp35-abi3-macosx_10_9_universal2.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.7 MB/s eta 0:00:00ta 0:00:01
# Collecting future>=0.6.0 (from bce-python-sdk->visualdl->paddleocr>=2.0.1)
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 58.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (6.1.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from pandas->visualdl->paddleocr>=2.0.1) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from requests->premailer->paddleocr>=2.0.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from requests->premailer->paddleocr>=2.0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from requests->premailer->paddleocr>=2.0.1) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from requests->premailer->paddleocr>=2.0.1) (2023.7.22)
# Requirement already satisfied: zipp>=0.5 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages (from Jinja2>=3.1.2->flask>=1.1.1->visualdl->paddleocr>=2.0.1) (2.1.3)
# Building wheels for collected packages: PyMuPDF, lmdb, lxml, future
#   Building wheel for PyMuPDF (setup.py) ... -^C
# anceled
# ERROR: Operation cancelled by user
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from paddleocr import PaddleOCR,draw_ocr
# Paddleocr supports Chinese, English, French, German, Korean and Japanese.
# You can set the parameter `lang` as `ch`, `en`, `french`, `german`, `korean`, `japan`
# to switch the language model in order.
ocr = PaddleOCR(use_angle_cls=True, lang='en') # need to run only once to download and load model into memory
img_path = 'PaddleOCR/doc/imgs_en/img_12.jpg'
result = ocr.ocr(img_path, cls=True)
for idx in range(len(result)):
    res = result[idx]
    for line in res:
        print(line)
