# %% [markdown]
# # XGBoost sklearn

# %% [markdown]
# XGBoostをsklearnインタフェースで簡単に利用するためのものです．XGBoostのすべての機能は実装されていません．

# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyu-quant/data-science-wiki/blob/develop/tabledata/binary_classification/XGBoost_sklearn.ipynb" target="_blank" rel="noopener noreferrer"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install xgboost

# %%
import xgboost as xgb

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# ### データの用意

# %%
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
x = df.drop('target', axis = 1)
y = df['target']

X_train, X_valid, y_train, y_valid = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### XGBoostの学習

# %%
clf = xgb.XGBClassifier(
    objective='binary:logistic', 
    eval_metric='logloss', 
    use_label_encoder=False,
    n_estimators=100, 
    learning_rate=0.05
)
clf.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
# Out:
# [0]	validation_0-logloss:0.62490
# [1]	validation_0-logloss:0.58922
# [2]	validation_0-logloss:0.55615
# [3]	validation_0-logloss:0.52801
# [4]	validation_0-logloss:0.49994
# [5]	validation_0-logloss:0.47483
# [6]	validation_0-logloss:0.45161
# [7]	validation_0-logloss:0.43165
# [8]	validation_0-logloss:0.41193
# [9]	validation_0-logloss:0.39412
# [10]	validation_0-logloss:0.37819
# [11]	validation_0-logloss:0.36284
# [12]	validation_0-logloss:0.34885
# [13]	validation_0-logloss:0.33544
# [14]	validation_0-logloss:0.32340
# [15]	validation_0-logloss:0.31280
# [16]	validation_0-logloss:0.30159
# [17]	validation_0-logloss:0.28995
# [18]	validation_0-logloss:0.27905
# [19]	validation_0-logloss:0.26884
# [20]	validation_0-logloss:0.26079
# [21]	validation_0-logloss:0.25172
# [22]	validation_0-logloss:0.24320
# [23]	validation_0-logloss:0.23651
# [24]	validation_0-logloss:0.22926
# [25]	validation_0-logloss:0.22341
# [26]	validation_0-logloss:0.21762
# [27]	validation_0-logloss:0.21158
# ...

# %% [markdown]
# ### 予測

# %%
y_pred = clf.predict(X_valid)
# Out:
# /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages/xgboost/data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages/xgboost/data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# /Users/tanakatouma/vscode/data-science-wiki/.venv/lib/python3.9/site-packages/xgboost/data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# ...

# %%
auc = roc_auc_score(y_valid, y_pred)
print(f'AUC: {auc}')
# Out:
# AUC: 0.9510317720275139
