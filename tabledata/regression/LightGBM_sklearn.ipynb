# %% [markdown]
# # LightGBM sklearn

# %% [markdown]
# LightGBMをsklearnインタフェースで簡単に利用するためのものです．LightGBMのすべての機能は実装されていません．

# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyu-quant/data-science-wiki/blob/develop/tabledata/regression/LightGBM_sklearn.ipynb" target="_blank" rel="noopener noreferrer"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install lightgbm

# %%
import lightgbm as lgb

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# ### データの用意

# %%
california = fetch_california_housing()
df = pd.DataFrame(california.data, columns=california.feature_names)
df['target'] = pd.Series(california.target, name='MedHouseVal')
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
x = df.drop('target', axis = 1)
y = df['target']

X_train, X_valid, y_train, y_valid = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### LightGBMの学習

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'n_estimators': 100,
    'random_state': 42
}

# %%
regressor = lgb.LGBMRegressor(**params)
regressor.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000572 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1838
# [LightGBM] [Info] Number of data points in the train set: 16512, number of used features: 8
# [LightGBM] [Info] Start training from score 2.071947
# LGBMRegressor(learning_rate=0.05, metric='rmse', objective='regression',
#               random_state=42)

# %% [markdown]
# ### 予測

# %%
y_pred = regressor.predict(X_valid)

# %%
# 平均二乗誤差 (MSE) の計算
mse = mean_squared_error(y_valid, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.2383596246449657
